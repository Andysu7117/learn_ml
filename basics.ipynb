# %%
print("This is a code cell")
# Out:
# This is a code cell

# %%
variable = "right in the strings"
print(f"f strings allow you to embes variable {variable}")
# Out:
# f strings allow you to embes variable right in the strings
